# %%
library("ggplot2")
library("RColorBrewer")
library("magrittr")
library("cowplot")
library("ggrepel")
library("grid")
library("readr")
library("stringr")
library("dplyr")
library("tibble")
library("tidyr")
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: 'tidyr'
#
#
# The following object is masked from 'package:magrittr':
#
#     extract

# %%
df = read_table("/users/mkelsey/data/senescence/results/agg/repeatanalysis/resultsdf.tsv")
# Out:
# -- Column specification --------------------------------------------------------
# cols(
#   .default = col_double(),
#   Geneid = col_character(),
#   tlt = col_character(),
#   Significance_condition_SEN_vs_PRO = col_character(),
#   X3TC1 = col_character(),
#   teorgenename = col_character(),
#   chr = col_character(),
#   start = col_character(),
#   stop = col_character(),
#   strand = col_character(),
#   exonOverlapCount = col_character(),
#   region = col_character(),
#   region2 = col_character(),
#   length = col_character(),
#   Family = col_character(),
#   ActiveFamily = col_character(),
#   Subfamily = col_character()
# )
# i Use `spec()` for the full column specifications.
#
# Warning message:
# "384468 parsing failures.
# row col   expected     actual                                                                      file
#   5  -- 64 columns 66 columns '/users/mkelsey/data/senescence/results/agg/repeatanalysis/resultsdf.tsv'
# ...

# %%
df
# Out:
#         Geneid                                       tlt
# 1       (CATTC)n_dup1:(CATTC)n:Satellite:Satellite   telocal_multi
# 2       (CATTC)n_dup1:(CATTC)n:Satellite:Satellite   telocal_uniq
# 3       (CATTC)n_dup10:(CATTC)n:Satellite:Satellite  telocal_multi
# 4       (CATTC)n_dup10:(CATTC)n:Satellite:Satellite  telocal_uniq
# 5       (CATTC)n_dup100:(CATTC)n:Satellite:Satellite telocal_multi
# 6       (CATTC)n_dup100:(CATTC)n:Satellite:Satellite telocal_uniq
# 7       (CATTC)n_dup101:(CATTC)n:Satellite:Satellite telocal_multi
# 8       (CATTC)n_dup101:(CATTC)n:Satellite:Satellite telocal_uniq
# 9       (CATTC)n_dup102:(CATTC)n:Satellite:Satellite telocal_multi
# 10      (CATTC)n_dup102:(CATTC)n:Satellite:Satellite telocal_uniq
# 11      (CATTC)n_dup103:(CATTC)n:Satellite:Satellite telocal_multi
# 12      (CATTC)n_dup103:(CATTC)n:Satellite:Satellite telocal_uniq
# 13      (CATTC)n_dup104:(CATTC)n:Satellite:Satellite telocal_multi
# ...

# %%
df %>% filter(Subfamily == "L1HS") %$% Significance_condition_SEN_vs_PRO %>% unique()
# Out:
# [1] NA
